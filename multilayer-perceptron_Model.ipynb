# %%
import pandas as pd
import numpy as np 

Room_data=pd.read_csv("C:\\Users\\DIVESH\\Documents\\Occupancy_Estimation.csv")
print(Room_data.head())
print(Room_data['Room_Occupancy_Count'].unique())
# Out:
#          Date      Time  S1_Temp  S2_Temp  S3_Temp  S4_Temp  S1_Light  \
# 0  2017/12/22  10:49:41    24.94    24.75    24.56    25.38       121
# 1  2017/12/22  10:50:12    24.94    24.75    24.56    25.44       121
# 2  2017/12/22  10:50:42    25.00    24.75    24.50    25.44       121
# 3  2017/12/22  10:51:13    25.00    24.75    24.56    25.44       121
# 4  2017/12/22  10:51:44    25.00    24.75    24.56    25.44       121
#
#    S2_Light  S3_Light  S4_Light  S1_Sound  S2_Sound  S3_Sound  S4_Sound  \
# 0        34        53        40      0.08      0.19      0.06      0.06
# 1        33        53        40      0.93      0.05      0.06      0.06
# 2        34        53        40      0.43      0.11      0.08      0.06
# 3        34        53        40      0.41      0.10      0.10      0.09
# 4        34        54        40      0.18      0.06      0.06      0.06
#
#    S5_CO2  S5_CO2_Slope  S6_PIR  S7_PIR  Room_Occupancy_Count
# ...

# %%
Room_data.shape
# Out:
# (10129, 19)

# %%
Room_data.describe(include='all')
# Out:
#               Date      Time       S1_Temp       S2_Temp       S3_Temp  \
# count        10129     10129  10129.000000  10129.000000  10129.000000
# unique           7     10129           NaN           NaN           NaN
# top     2017/12/23  10:49:41           NaN           NaN           NaN
# freq          2779         1           NaN           NaN           NaN
# mean           NaN       NaN     25.454012     25.546059     25.056621
# std            NaN       NaN      0.351351      0.586325      0.427283
# min            NaN       NaN     24.940000     24.750000     24.440000
# 25%            NaN       NaN     25.190000     25.190000     24.690000
# 50%            NaN       NaN     25.380000     25.380000     24.940000
# 75%            NaN       NaN     25.630000     25.630000     25.380000
# max            NaN       NaN     26.380000     29.000000     26.190000
#
#              S4_Temp      S1_Light     S2_Light      S3_Light      S4_Light  \
# ...

# %%
x = Room_data[[ 'S1_Temp' , 'S2_Temp' , 'S3_Temp' , 'S4_Temp' , 'S1_Light' , 'S2_Light' , 'S3_Light' , 'S4_Light' , 'S1_Sound' , 'S2_Sound' , 'S3_Sound' , 'S4_Sound' , 'S5_CO2' ,'S5_CO2_Slope' ]]
y= Room_data[['S6_PIR', 'S7_PIR','Room_Occupancy_Count']]

# %%
print(y)
# Out:
#        S6_PIR  S7_PIR  Room_Occupancy_Count
# 0           0       0                     1
# 1           0       0                     1
# 2           0       0                     1
# 3           0       0                     1
# 4           0       0                     1
# ...       ...     ...                   ...
# 10124       0       0                     0
# 10125       0       0                     0
# 10126       0       0                     0
# 10127       0       0                     0
# 10128       0       0                     0
#
# [10129 rows x 3 columns]

# %%
print(x)
# Out:
#        S1_Temp  S2_Temp  S3_Temp  S4_Temp  S1_Light  S2_Light  S3_Light  \
# 0        24.94    24.75    24.56    25.38       121        34        53
# 1        24.94    24.75    24.56    25.44       121        33        53
# 2        25.00    24.75    24.50    25.44       121        34        53
# 3        25.00    24.75    24.56    25.44       121        34        53
# 4        25.00    24.75    24.56    25.44       121        34        54
# ...        ...      ...      ...      ...       ...       ...       ...
# 10124    25.06    25.13    24.69    25.31         6         7        33
# 10125    25.06    25.06    24.69    25.25         6         7        34
# 10126    25.13    25.06    24.69    25.25         6         7        34
# 10127    25.13    25.06    24.69    25.25         6         7        34
# 10128    25.13    25.06    24.69    25.25         6         7        34
#
#        S4_Light  S1_Sound  S2_Sound  S3_Sound  S4_Sound  S5_CO2  S5_CO2_Slope
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=0)
print(x_train.shape)
print(y_test.shape)
# Out:
# (9116, 14)
# (1013, 3)

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp = MLPClassifier(hidden_layer_sizes=(3,2) , activation='relu')
mlp.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22136/106455646.py in <module>
#       1 mlp = MLPClassifier(hidden_layer_sizes=(3,2) , activation='relu')
# ----> 2 mlp.fit(x_train,y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py in fit(self, X, y)
#     671         self : returns a trained MLP model.
#     672         """
# --> 673         return self._fit(X, y, incremental=False)
#     674
#     675     @property
#
# ~\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py in _fit(self, X, y, incremental)
#     362                       (not self.warm_start and not incremental))
#     363
# --> 364         X, y = self._validate_input(X, y, incremental, reset=first_pass)
#     365
#     366         n_samples, n_features = X.shape
#
# ...
